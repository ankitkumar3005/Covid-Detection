# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv("italy-covid19.csv")

# %%
data
# Out:
#        SNo                 Date  ... TotalPositiveCases  TestsPerformed
# 0        0  2020-02-24T18:00:00  ...                  0             NaN
# 1        1  2020-02-24T18:00:00  ...                  0             NaN
# 2        2  2020-02-24T18:00:00  ...                  0             NaN
# 3        3  2020-02-24T18:00:00  ...                  0             NaN
# 4        4  2020-02-24T18:00:00  ...                  0             NaN
# ...    ...                  ...  ...                ...             ...
# 1549  1549  2020-05-07T17:00:00  ...               9683        124295.0
# 1550  1550  2020-05-07T17:00:00  ...               4283         28486.0
# 1551  1551  2020-05-07T17:00:00  ...               1405         29708.0
# 1552  1552  2020-05-07T17:00:00  ...               1150          6702.0
# 1553  1553  2020-05-07T17:00:00  ...              18553        236281.0
#
# [1554 rows x 17 columns]

# %%
data.head()
# Out:
#    SNo                 Date Country  ...  Deaths TotalPositiveCases  TestsPerformed
# 0    0  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 1    1  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 2    2  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 3    3  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 4    4  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
#
# [5 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.describe()
# Out:
#                SNo   RegionCode  ...  TotalPositiveCases  TestsPerformed
# count  1554.000000  1554.000000  ...         1554.000000      399.000000
# mean    776.500000    10.190476  ...         4906.436293    60236.165414
# std     448.745474     5.796929  ...        11182.859173    59613.663756
# min       0.000000     1.000000  ...            0.000000     3482.000000
# 25%     388.250000     5.000000  ...          188.750000    20802.500000
# 50%     776.500000    10.000000  ...         1232.000000    35443.000000
# 75%    1164.750000    15.000000  ...         3993.250000    88246.500000
# max    1553.000000    20.000000  ...        80089.000000   262964.000000
#
# [8 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
data.describe()
# Out:
#                SNo   RegionCode  ...  TotalPositiveCases  TestsPerformed
# count  1554.000000  1554.000000  ...         1554.000000      399.000000
# mean    776.500000    10.190476  ...         4906.436293    60236.165414
# std     448.745474     5.796929  ...        11182.859173    59613.663756
# min       0.000000     1.000000  ...            0.000000     3482.000000
# 25%     388.250000     5.000000  ...          188.750000    20802.500000
# 50%     776.500000    10.000000  ...         1232.000000    35443.000000
# 75%    1164.750000    15.000000  ...         3993.250000    88246.500000
# max    1553.000000    20.000000  ...        80089.000000   262964.000000
#
# [8 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.relplot(x ="TotalHospitalizedPatients",y="Recovered",data=data)

# %%
sns.relplot(x ="TotalPositiveCases",y="Deaths",data=data)

# %%
sns.relplot(x="TestsPerformed",y ="Deaths",data=data)

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.relplot(x = "TotalPositiveCases", y ="HospitalizedPatients",hue = "Recovered",data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.relplot(x ="Recovered", y ="HomeConfinement",kind ="line", data=data)

# %%
sns.catplot(x="TotalPositiveCases",y ="Recovered",data=data)

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.catplot(x ="TotalPositiveCases",y= "Deaths",data=data)
